# %% [markdown]
# <h1>Installing Requests module</h1>

# %%
pip install requests

# %% [markdown]
# <h1>Installing MySql-Connector module</h1>

# %%
pip install mysql-connector-python

# %%
import pandas as pd

# %% [markdown]
# <h1>Creating API request</h1>

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3NmY1NDQ0NjdhZDM0ZTVhYzI0Y2FkODhkMjY5OWMwOSIsIm5iZiI6MTcyMTY2MjkyNy4wODY1NCwic3ViIjoiNjY5ZTdjMDRmYTA2ZTE5MDdlNmU1NWVmIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.pCG1jC2YjYvN0lpZOKG2ghUuyoJnei6v9rEvuCE5E1w"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg', 'genre_ids': [18, 80], 'id': 278, 'original_language': 'en', 'original_title': 'The Shawshank Redemption', 'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.', 'popularity': 157.956, 'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg', 'release_date': '1994-09-23', 'title': 'The Shawshank Redemption', 'video': False, 'vote_average': 8.706, 'vote_count': 26479}, {'adult': False, 'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg', 'genre_ids': [18, 80], 'id': 238, 'original_language': 'en', 'original_title': 'The Godfather', 'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.', 'popularity': 136.656, 'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg', 'release_date': '1972-03-14', 'title': 'The Godfather', 'video': False, 'vote_average': 8.692, 'vote_count': 20103}, {'adult': False, 'backdrop_path': '/b6w7gKLQLS2zw4JK0XmKgQ4gnzr.jpg', 'genre_ids': [18, 80], 'id': 240, 'original_language': 'en', 'original_title': 'The Godfather Part II', 'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.', 'popularity': 103.989, 'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg', 'release_date': '1974-12-20', 'title': 'The Godfather Part II', 'video': False, 'vote_average': 8.577, 'vote_count': 12131}, {'adult': False, 'backdrop_path': '/zb6fM1CX41D9rF9hdgclu0peUmy.jpg', 'genre_ids': [18, 36, 10752], 'id': 424, 'original_language': 'en', 'original_title': "Schindler's List", 'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.', 'popularity': 101.993, 'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg', 'release_date': '1993-12-15', 'title': "Schindler's List", 'video': False, 'vote_average': 8.567, 'vote_count': 15531}, {'adult': False, 'backdrop_path': '/qqHQsStV6exghCM7zbObuYBiYxw.jpg', 'genre_ids': [18], 'id': 389, 'original_language': 'en', 'original_title': '12 Angry Men', 'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.", 'popularity': 70.114, 'poster_path': '/ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg', 'release_date': '1957-04-10', 'title': '12 Angry Men', 'video': False, 'vote_average': 8.5, 'vote_count': 8381}, {'adult': False, 'backdrop_path': '/m4TUa2ciEWSlk37rOsjiSIvZDXE.jpg', 'genre_ids': [16, 10751, 14], 'id': 129, 'original_language': 'ja', 'original_title': '千と千尋の神隠し', 'overview': 'A young girl, Chihiro, becomes trapped in a strange new world of spirits. When her parents undergo a mysterious transformation, she must call upon the courage she never knew she had to free her family.', 'popularity': 135.777, 'poster_path': '/39wmItIWsg5sZMyRUHLkWBcuVCM.jpg', 'release_date': '2001-04-18', 'title': 'Spirited Away', 'video': False, 'vote_average': 8.537, 'vote_count': 16133}, {'adult': False, 'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg', 'genre_i ...

# %% [markdown]
# <h1>Converting API response to dataframe</h1>

# %%
df = pd.DataFrame(response.json()['results'])[['title', 'release_date','original_language','adult','popularity','overview','vote_count','vote_average']]

# %%
df.head()
# Out:
#                       title release_date original_language  adult  popularity  \
# 0  The Shawshank Redemption   1994-09-23                en  False     157.956
# 1             The Godfather   1972-03-14                en  False     136.656
# 2     The Godfather Part II   1974-12-20                en  False     103.989
# 3          Schindler's List   1993-12-15                en  False     101.993
# 4              12 Angry Men   1957-04-10                en  False      70.114
#
#                                             overview  vote_count  vote_average
# 0  Imprisoned in the 1940s for the double murder ...       26479         8.706
# 1  Spanning the years 1945 to 1955, a chronicle o...       20103         8.692
# 2  In the continuing saga of the Corleone crime f...       12131         8.577
# 3  The true story of how businessman Oskar Schind...       15531         8.567
# 4  The defense and the prosecution have rested an...        8381         8.500

# %% [markdown]
# <h1>Collecting Data from all pages from responses</h1>

# %%
for  i in range(2,477):
    url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i)
    response = requests.get(url, headers=headers)
    temp_df = pd.DataFrame(response.json()['results'])[['title', 'release_date','original_language','adult','popularity','overview','vote_count','vote_average']]
    df= pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#                            title release_date original_language  adult  \
# 0       The Shawshank Redemption   1994-09-23                en  False
# 1                  The Godfather   1972-03-14                en  False
# 2          The Godfather Part II   1974-12-20                en  False
# 3               Schindler's List   1993-12-15                en  False
# 4                   12 Angry Men   1957-04-10                en  False
# ...                          ...          ...               ...    ...
# 9506           Alone in the Dark   2005-01-28                en  False
# 9507              Disaster Movie   2008-08-29                en  False
# 9508           House of the Dead   2003-04-11                en  False
# 9509        Dragonball Evolution   2009-03-12                en  False
# 9510  Birdemic: Shock and Terror   2010-02-27                en  False
#
#       popularity                                           overview  \
# 0        157.956  Imprisoned in the 1940s for the double murder ...
# 1        136.656  Spanning the years 1945 to 1955, a chronicle o...
# 2        103.989  In the continuing saga of the Corleone crime f...
# 3        101.993  The true story of how businessman Oskar Schind...
# 4         70.114  The defense and the prosecution have rested an...
# ...          ...                                                ...
# 9506      17.289  Edward Carnby is a private investigator specia...
# 9507      22.492  Over the course of one evening, an unsuspectin...
# 9508      14.217  Set on an island off the coast, a techno rave ...
# 9509      24.649  On his 18th birthday, Goku receives a mystical...
# 9510       7.763  A platoon of eagles and vultures attacks the r...
#
#       vote_count  vote_average
# 0          26479         8.706
# 1          20103         8.692
# 2          12131         8.577
# 3          15531         8.567
# 4           8381         8.500
# ...          ...           ...
# 9506         590         3.245
# 9507        1007         3.200
# 9508         374         3.139
# 9509        1999         2.900
# 9510         326         2.184
#
# [9511 rows x 8 columns]

# %%
df.to_csv("Top_rated_movies.csv")

# %% [markdown]
# <h1>Connecting the sql server</h1>

# %%
import mysql.connector
import os

# List of CSV files and their corresponding table names
csv_files = [
    ('Top_rated_movies.csv', 'Top_rated_movies'),
]

# Connect to the MySQL database
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='J3p$Rm7q',
    database='Top_rated_movies'
)
cursor = conn.cursor()

# Folder containing the CSV files
folder_path = r'C:\Users\HP\Desktop\Pyhton + SQL project'

def get_sql_type(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return 'INT'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'DATETIME'
    else:
        return 'TEXT'

for csv_file, table_name in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    df = pd.read_csv(file_path)
    
    df = df.where(pd.notnull(df), None)
    
    print(f"Processing {csv_file}")
    print(f"NaN values before replacement:\n{df.isnull().sum()}\n")

    df.columns = [col.replace(' ', '_').replace('-', '_').replace('.', '_') for col in df.columns]

    columns = ', '.join([f'`{col}` {get_sql_type(df[col].dtype)}' for col in df.columns])
    create_table_query = f'CREATE TABLE IF NOT EXISTS `{table_name}` ({columns})'
    cursor.execute(create_table_query)

    for _, row in df.iterrows():
        
        values = tuple(None if pd.isna(x) else x for x in row)
        sql = f"INSERT INTO `{table_name}` ({', '.join(['`' + col + '`' for col in df.columns])}) VALUES ({', '.join(['%s'] * len(row))})"
        cursor.execute(sql, values)

    conn.commit()

# Close the connection
conn.close()
# Out:
# Processing Top_rated_movies.csv
# NaN values before replacement:
# Unnamed: 0           0
# title                0
# release_date         0
# original_language    0
# adult                0
# popularity           0
# overview             2
# vote_count           0
# vote_average         0
# dtype: int64
